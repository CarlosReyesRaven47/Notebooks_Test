# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram,linkage
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import inconsistent
from scipy.cluster.hierarchy import fcluster

# %%
df1=pd.read_csv('places_details (3).csv')
df2=pd.read_csv('places_reviews (3).csv')
df1
# Out:
#                         place_id                            name  \
# 0    ChIJ_6PxIP_-0YURb-iv-Yq3gPM  La Cocina Tradicional Mexicana
# 1    ChIJ06Wq3J4BzoUREnZuxiDcPo8                   Candelilla 16
# 2    ChIJ0-IjfKoDzoURrhSoInEmyrs     Antojitos Méxicanos Don Max
# 3    ChIJ0RedUVYCzoURQcJ0Bo5LJew                   Rico Amanecer
# 4    ChIJ0Vr0QeUB0oURZfWZGMhVCpg             El Lago Restaurante
# ..                           ...                             ...
# 109  ChIJU67OTNv_0YURj-nw92FLYDc           Pepe Coyotes Coyoacán
# 110  ChIJITgvvy__0YUR0fZG9xzbMO4                        La Tecla
# 111  ChIJ0Z9P0z7_0YURVqrnz-OpFms                    Mercado Roma
# 112  ChIJY3GHMuT_0YURoETJ-mqSwEo            MercadoRoma Coyoacán
# 113  ChIJRU2FLk__0YURikrh-RZMung     El Pialadero de Guadalajara
#
#     business_status   latitude  longitude  user_ratings_total  rating  \
# 0       OPERATIONAL  19.388755 -99.141413                 104     4.5
# ...

# %%
lista_restaurantes=df1['name'].tolist()
lista_restaurantes
ids_restaurantes=df1['place_id'].tolist()
ids_restaurantes
# Out:
# ['ChIJ_6PxIP_-0YURb-iv-Yq3gPM',
#  'ChIJ06Wq3J4BzoUREnZuxiDcPo8',
#  'ChIJ0-IjfKoDzoURrhSoInEmyrs',
#  'ChIJ0RedUVYCzoURQcJ0Bo5LJew',
#  'ChIJ0Vr0QeUB0oURZfWZGMhVCpg',
#  'ChIJ21LyB_f_0YURW_F1RfqWhiI',
#  'ChIJ2aMgewj_0YURpdcFaz8FMgs',
#  'ChIJ2bbY7Dv-0YURUiiWvISOsIM',
#  'ChIJ2YvzBf7_0YUR8sk-6mA9wG8',
#  'ChIJ3xty5nT_0YUR3YiY2g8h1b0',
#  'ChIJ48KvaD7_0YURhzmZCryLbSw',
#  'ChIJ4ftOXEH-zYUREp_SkJ49kVI',
#  'ChIJ6aAgy3740YURlAM6t3ylxuk',
#  'ChIJ6QlgPHr40YURLu6gEG4Y5m0',
#  'ChIJ7w5HFPj_0YURHTyE1LwPB_c',
#  'ChIJ7WAfwbv_0YURiSIZGMdRuto',
#  'ChIJ9fq-YdH-0YURa3zaK7Gz8lc',
#  'ChIJa1lZNZ__0YURjDHz4gNWVQc',
#  'ChIJASya8GX50YURN0r_0oVNXTU',
#  'ChIJBa69bJkC0oURgUnOYp0Jiuw',
#  'ChIJBeL1vQj_0YURMcKqVViw2ok',
#  'ChIJbS0fR3740YUR9YaIL0WpqpU',
#  'ChIJbS8EZf8B0oURwwD8B0MpqK0',
#  'ChIJCacXGY350YURPOvR1VMkAl0',
#  'ChIJCb0mr30C0oURB9O4eiWffhc',
#  'ChIJcXkqTmP_0YURgL7SkW2AGaY',
#  'ChIJD08EXM340YURzuNh3vsiCYs',
#  'ChIJeYLOZMT_0YURFEhp2ubb43c',
#  'ChIJF8Q-YKoDzoURlfezp6Xfjp0',
# ...

# %%
df2=df2.dropna()
df2
# Out:
#                                                     url            reviewer  \
# 0     https://www.google.com/maps/reviews/data=!4m5!...        Josial Iszsa
# 1     https://www.google.com/maps/reviews/data=!4m5!...   Osvaldo Caballero
# 2     https://www.google.com/maps/reviews/data=!4m5!...       Marbella Miss
# 3     https://www.google.com/maps/reviews/data=!4m5!...  Erick romero casas
# 4     https://www.google.com/maps/reviews/data=!4m5!...     Yoscelina Gomez
# ...                                                 ...                 ...
# 9178  https://www.google.com/maps/reviews/data=!4m5!...     Alejandro Trias
# 9179  https://www.google.com/maps/reviews/data=!4m5!...       Denisse Silva
# 9180  https://www.google.com/maps/reviews/data=!4m5!...        Aanthony Lgn
# 9181  https://www.google.com/maps/reviews/data=!4m5!...      Javier Morales
# 9182  https://www.google.com/maps/reviews/data=!4m5!...    Alejandro Chavez
#
# ...

# %%
df3=pd.read_excel('places_contenido.xlsx',sheet_name='resenas')
df3#esto se hizo con buscarv en excel
# Out:
#                                                     url            reviewer  \
# 0     https://www.google.com/maps/reviews/data=!4m5!...        Josial Iszsa
# 1     https://www.google.com/maps/reviews/data=!4m5!...   Osvaldo Caballero
# 2     https://www.google.com/maps/reviews/data=!4m5!...       Marbella Miss
# 3     https://www.google.com/maps/reviews/data=!4m5!...  Erick romero casas
# 4     https://www.google.com/maps/reviews/data=!4m5!...     Yoscelina Gomez
# ...                                                 ...                 ...
# 9178  https://www.google.com/maps/reviews/data=!4m5!...     Alejandro Trias
# 9179  https://www.google.com/maps/reviews/data=!4m5!...       Denisse Silva
# 9180  https://www.google.com/maps/reviews/data=!4m5!...        Aanthony Lgn
# 9181  https://www.google.com/maps/reviews/data=!4m5!...      Javier Morales
# 9182  https://www.google.com/maps/reviews/data=!4m5!...    Alejandro Chavez
#
# ...

# %%
df4=pd.concat([df3['name_local'],df3['rating'],df3['text'].str.split(",",expand=True)],axis=1)

# %%
df4.to_csv('resenas_restaurantes.csv',index=False,encoding='utf-8')
